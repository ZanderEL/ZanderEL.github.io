# %% [markdown]
# # **NOTE:** Use File > Save a copy in Drive to make a copy before doing anything else

# %% [markdown]
# # Project 7: Student Habits vs Academic Performance Analysis

# %% [markdown]
# #### Overview

# %% [markdown]
# This project analyzes the relationship between student lifestyle habits and academic performance using a comprehensive dataset from Kaggle. The dataset contains information about 1,000 students and includes 16 variables covering various aspects of student life, including study habits, social media usage, sleep patterns, diet quality, exercise frequency, and academic outcomes.
#
# The analysis focuses on understanding how different study patterns correlate with exam performance.The project demonstrates fundamental data analysis skills including data cleaning, statistical calculations, and comparative analysis using Python and pandas.

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
# Update file_path to point to the specific file within the dataset
file_path = "student_habits_performance.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "jayaantanaath/student-habits-vs-academic-performance",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /tmp/ipython-input-519/3453289196.py:11: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# Using Colab cache for faster access to the 'student-habits-vs-academic-performance' dataset.
# First 5 records:   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
# 2         Poor                   1              High School             Poor
# 3         Poor                   4                   Master             Good
# 4         Fair                   3                   Master             Good
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0
# 2                     1                            No        34.3
# 3                     1                           Yes        26.8
# 4                     1                            No        66.4

# %%
one_col = df['age']

# %%
type(one_col)
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
#  12  internet_quality               1000 non-null   object
#  13  mental_health_rating           1000 non-null   int64
#  14  extracurricular_participation  1000 non-null   object
#  15  exam_score                     1000 non-null   float64
# dtypes: float64(6), int64(3), object(7)
# memory usage: 125.1+ KB

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %% [markdown]
# ### clean the data

# %%
df.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %% [markdown]
# This checks how many missing (NaN) values are in each column of the DataFrame. Based on the output:
#
# All columns have 0 missing values except for parental_education_level, which has 91 missing values.

# %% [markdown]
# The dataset is mostly clean, but you do need to clean or handle the missing data in the parental_education_level column.

# %% [markdown]
# #### Fill with a default or common value

# %% [markdown]
# #### drop rows with missing values

# %%
df.dropna(subset=['parental_education_level'], inplace=True)

# %%
# checking the data again
df.isnull().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %% [markdown]
# ### Questions to Answer
#
# Please find the answer for the following questoins.

# %% [markdown]
# 1. Find the average study hours per day for all students. Please create a code cell below this to answer the question.(0.5 point)

# %%
average_study_hours = df['study_hours_per_day'].mean()
print(f"Average study hours per day for all students: {average_study_hours:.2f} hours")
# Out:
# Average study hours per day for all students: 3.54 hours

# %% [markdown]
# 2. Identify the student who studies MOST hours per day. Please create a code cell below to answer the question.(0.5 point)

# %%
max_study_hours = df['study_hours_per_day'].max()
student_most_hours = df[df['study_hours_per_day'] == max_study_hours][['student_id', 'study_hours_per_day']]
print("Student(s) with the most study hours per day:")
print(student_most_hours)
# Out:
# Student(s) with the most study hours per day:
#     student_id  study_hours_per_day
# 455      S1455                  8.3

# %% [markdown]
# 3. Count how many students study more than 6 hours per day. Please create a code cell below this to answer the question.(0.5 point)

# %%
students_more_than_6_hours = df[df['study_hours_per_day'] > 6]
count_students_more_than_6 = students_more_than_6_hours.shape[0]
print(f"Number of students studying more than 6 hours per day: {count_students_more_than_6}")
# Out:
# Number of students studying more than 6 hours per day: 40

# %% [markdown]
# 4. What is the percentage of students who study more than 6 hours per day. Please create a code cell below this to answer the question.(0.5 point)

# %%
total_students = df.shape[0]
percentage_more_than_6_hours = (count_students_more_than_6 / total_students) * 100
print(f"Percentage of students studying more than 6 hours per day: {percentage_more_than_6_hours:.2f}%")
# Out:
# Percentage of students studying more than 6 hours per day: 4.40%

# %% [markdown]
# 5. Calculate what percentage of students study less than 2 hours per day. Please create a code cell below this to answer the question.(0.5 point)

# %%
students_less_than_2_hours = df[df['study_hours_per_day'] < 2]
count_students_less_than_2 = students_less_than_2_hours.shape[0]

# total_students is already available from previous steps as 909
# total_students = df.shape[0]

percentage_less_than_2_hours = (count_students_less_than_2 / total_students) * 100
print(f"Percentage of students studying less than 2 hours per day: {percentage_less_than_2_hours:.2f}%")
# Out:
# Percentage of students studying less than 2 hours per day: 13.53%

# %% [markdown]
# 6. Do students who study more than 5 hours per day have higher exam scores on average? Please create a code cell below to answer this question. (0.5 point)

# %%
high_study_hours = df[df['study_hours_per_day'] > 5]
low_study_hours = df[df['study_hours_per_day'] <= 5]

average_exam_score_high_study = high_study_hours['exam_score'].mean()
average_exam_score_low_study = low_study_hours['exam_score'].mean()

print(f"Average exam score for students studying more than 5 hours/day: {average_exam_score_high_study:.2f}")
print(f"Average exam score for students studying 5 hours or less/day: {average_exam_score_low_study:.2f}")
# Out:
# Average exam score for students studying more than 5 hours/day: 91.12
# Average exam score for students studying 5 hours or less/day: 65.67

# %% [markdown]
# 7. Use "Explain code" for the code you produced for Question 6 and summarize in your own words to show that you understood the code Gemini produced. Please create a text cell below to answer this question. (0.5 point)

# %% [markdown]
# Compares the average exam scores to hours studied by dividing students into groups of those who studied over 5 hours and under 5 hours. Then it calculates the average exam score for each of the groups and prints the 2 average scores to showif students that studied more have a higher exam score.

# %% [markdown]
# 8. The codes produced to answer the questions use "vectorization"? Please justify your answer with an example. Please create a text cell below to answer this question. (0.5 point)

# %% [markdown]
# #### Yes, the codes produced to answer the questions extensively use "vectorization".
#
# Vectorization is a programming paradigm that allows operations to be applied to entire arrays or Series of data at once, rather than iterating through each element individually. This approach is highly optimized in libraries like pandas (which is built on NumPy), leading to much faster execution times, especially with large datasets.
#
# **Justification with an Example:**
#
# Consider the code used to answer Question 3, "Count how many students study more than 6 hours per day":
#
# ```python
# students_more_than_6_hours = df[df['study_hours_per_day'] > 6]
# ```
#
# In this line, `df['study_hours_per_day'] > 6` is a vectorized operation. Instead of looping through each student's `study_hours_per_day` to check if it's greater than 6, pandas applies this comparison to *all* values in the `study_hours_per_day` column simultaneously. This operation returns a boolean Series (e.g., `[False, True, False, ...]`) indicating for each student whether their study hours exceed 6. This boolean Series is then used to filter the DataFrame `df`, again in a vectorized manner, to select only the rows where the condition is `True`.
#
# This vectorized approach is far more efficient than an equivalent loop-based operation in Python, as the underlying computations are performed in highly optimized C or Fortran code.
